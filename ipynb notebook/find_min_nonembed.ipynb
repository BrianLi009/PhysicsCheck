# %%
G=Graph([(0, 18, None), (0, 19, None), (0, 20, None), (0, 21, None), (1, 15, None), (1, 16, None), (1, 17, None), (1, 21, None), (2, 13, None), (2, 14, None), (2, 17, None), (2, 20, None), (3, 11, None), (3, 12, None), (3, 16, None), (3, 19, None), (4, 9, None), (4, 10, None), (4, 14, None), (4, 18, None), (5, 8, None), (5, 10, None), (5, 12, None), (5, 15, None), (6, 7, None), (6, 10, None), (6, 11, None), (6, 13, None), (7, 8, None), (7, 9, None), (7, 13, None), (8, 9, None), (8, 12, None), (9, 18, None), (10, 11, None), (10, 14, None), (10, 15, None), (11, 16, None), (12, 19, None), (13, 20, None), (14, 17, None), (15, 21, None), (16, 17, None), (18, 21, None), (19, 20, None)])
G.show()
#this is the order-22 graph with no known minimum embedabble graph
# Out:
# Graphics object consisting of 68 graphics primitives

# %%
order_13=[]
for g in list(G.connected_subgraph_iterator(k=13)):
    if g.order() == 13:
        order_13.append(g)
print (len(order_13))
# Out:
# 276847

# %%
#find graph that exists both in order_13, and the geng non isomoprhic graph list
file1 = open('order13.txt', 'r')
Lines = file1.readlines()
order_13_gen=[]
 
count = 0
# Strips the newline character
for line in Lines:
    count += 1
    g6_string=(line.split(": ")[1][:-1])
    graph=Graph(g6_string)
    order_13_gen.append(graph)

# %%
for graph in order_13_gen:
    for graph_2 in order_13:
        if graph.is_isomorphic(graph_2):
            print (graph.graph6_string())
            break
# Out:
# L_GS?KJO@?aB~?
# L``?hR?K?K@H?N
# LJaCAOcC_Q?d?f

# %%
#After running the embedability check, we obtain 2 candidates:
candidates=[Graph("L``?hR?K?K@H?N"), Graph("LJaCAOcC_Q?d?f")]
for graph_1 in candidates:
    print (Graph(G).subgraph_search_count(graph_1))
    for g in min_non_embed_lst:
        if Graph(graph_1).subgraph_search_count(g) > 0:
            print (candidates.graph6_string())
# Out:
# 12
# 12

# %%
Graph("L``?hR?K?K@H?N").is_isomorphic(Graph("LJaCAOcC_Q?d?f"))
#interesting result, it's saying that this graph contain 2 minimum non embedable subgraph of order 13 up to isomorphism.
# Out:
# False

# %%
min_non_embed=[
"I?qa``eeO",
"ICOedPKL?",
"J?GX?dH`f_?",
"JsOH?`JH_i_",
"J@`ICC[Gv_?",
"J`hSA?hD_F_",
"JRPCSGoAgJ_",
"K_GTAQOP@KbK",
"K@QCAGdA_c~?",
"K_GP`GWBACoK",
"KAICH@@DOT^?",
"Kko_GC`C?b`q",
"K`?KA@se_YCX",
"Ks?I@?XDaTCi",
"Kt?G?DKOoqCo",
"KqCaC?[I_J?Z",
"K`?LAQOP@KbK",
]

min_non_embed_lst = []
for g6 in min_non_embed:
    min_non_embed_lst.append(Graph(g6))

# %%
for graph in min_non_embed_lst:
    print (graph.show())
# Out:
# Graphics object consisting of 27 graphics primitives
# None
# Graphics object consisting of 26 graphics primitives
# None
# Graphics object consisting of 28 graphics primitives
# None
# Graphics object consisting of 30 graphics primitives
# None
# Graphics object consisting of 29 graphics primitives
# None
# Graphics object consisting of 30 graphics primitives
# None
# Graphics object consisting of 30 graphics primitives
# None
# Graphics object consisting of 32 graphics primitives
# None
# Graphics object consisting of 32 graphics primitives
# None
# Graphics object consisting of 30 graphics primitives
# None
# Graphics object consisting of 32 graphics primitives
# None
# Graphics object consisting of 32 graphics primitives
# None
# Graphics object consisting of 33 graphics primitives
# None
# Graphics object consisting of 33 graphics primitives
# None
# Graphics object consisting of 31 graphics primitives
# None
# Graphics object consisting of 33 graphics primitives
# None
# ...

# %%
for graph in min_non_embed_lst:
    print (graph.degree_sequence())
# Out:
# [4, 4, 3, 3, 3, 3, 3, 3, 3, 3]
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2]
# [4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2]
# [5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3]
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3]
# [4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
for graph in min_non_embed_lst:
    print (graph.is_biconnected())
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
for graph in min_non_embed_lst:
    print (graph.is_bipartite())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
