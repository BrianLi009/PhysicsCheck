K_C?HCMmBAI`,
K_C_GCRQPW}C,
K_?`GgImAaHD,
K`K_GGQAQDGJ,
K_C?HGaDOTN?,
K_C?HGaDOT^?,
K_CH?CDCX[]A,
K`K_?SQ@AHoY,
K_C?HGamAiHS,
KAICH@@DOT^?,
KG?_gZ?CgRn?,
K?D@CQU]AICX,
Kko_GC`C?b`q,
K_C@?[SmAHKP,
K`?KAAYTPWCX,
K_C@@KKmAHIP,
K`?_O`BBcI~?,
K`?KA@se_YCX,
K_K__?XHaEok,
K?D@CQFT@clG,
K_G?L`SQ_edc,
Ks?I@?XDaTCi,
K?GXOiA_YdKI,
K`?H@CWDATGi,
K`?H@CWDCTGi,
K_C@@CLDAK~?,
K_?`G_HmAiHS,
KGC?HdKE?K{B,
K?@HOroP@CaJ,
KG?OUMwW?g`R,
K@OWACb_cWmA,
K@P@Oi?[GT?l,
K?GY@CRoCWmA,
Kt?G?DKOoqCo,
KyGO_WI_?I_V,
K?D@KiIW@ahE,
KK?AhqG`ITCi,
KhCK??ZHeA?j,
K`CcA?raaI@b,
KqGO?FAIOi`s,
K_GOT`COgedc,
KqCaC?[I_J?Z,
KBG?kEKOQHdI,
K@GGcIBSbPGi,
K?Ch_Y@O\DIQ,
KGO_sAFL?ahH,
K`GOGPAOXTAi,
K`?LAQOP@KbK,
K_CGL`_Ogedc,
KG?qSeKW?a`F,
K?XQCE@KpPAd,
KIO_cQFH?c`J,
K_CcSL_SHTAi"""
# Out:
# <>:276: DeprecationWarning: invalid escape sequence \[
# <>:276: DeprecationWarning: invalid escape sequence \[
# <>:276: DeprecationWarning: invalid escape sequence \[
# <ipython-input-14-622e51b9781a>:276: DeprecationWarning: invalid escape sequence \[
#   K_CcSL_SHTAi"""

# %%
graphs_2 = """
I?qa``eeO,
ICOedPKL?,
J?GX?dH`f_?,
J@`KACXHf_?,
JsOH?`JH_i_,
J@`ICC[Gv_?,
J`hSA?hD_F_,
JRPCSGoAgJ_,
K_OGPGRD@C}?,
K_GTAQOP@KbK,
K@QCAGdA_c~?,
KQ?GPGQPSD~?,
KGD?X?P`cB~?,
KqI?O`QIOL?j,
KoD@I_g_?e`e,
K_GP`GWBACoK,
KgA?gW_CWTN?,
KAICH@@DOT^?,
Kko_GC`C?b`q,
K`?_O`BBcI~?,
K`?KA@se_YCX,
Ks?I@?XDaTCi,
Kt?G?DKOoqCo,
KyGO_WI_?I_V,
K`CcA?raaI@b,
KqCaC?[I_J?Z,
K`?LAQOP@KbK
"""

# %%
def check_subgraph(graphs):
    non_minimal = []
    graph_lst = []
    for graph in list(graphs.split(",")):
        graph_lst.append(graph)
    for graph1 in graph_lst:
        for graph2 in graph_lst:
            if graph2 != graph1:
                graph_1 = graph1[1:]
                graph_2 = graph2[1:]
                if Graph(graph_1).subgraph_search_count(Graph(graph_2)) > 0:
                    non_minimal.append(graph_1)
                    break
    print (len(non_minimal))
    print (non_minimal)

# %%
check_subgraph(graphs_2)
# Out:
# 10
# ['J@`KACXHf_?', 'K_OGPGRD@C}?', 'KQ?GPGQPSD~?', 'KGD?X?P`cB~?', 'KqI?O`QIOL?j', 'KoD@I_g_?e`e', 'KgA?gW_CWTN?', 'K`?_O`BBcI~?', 'KyGO_WI_?I_V', 'K`CcA?raaI@b']

# %%
non_minimal = ['J@`KACXHf_?', 'K_OGPGRD@C}?', 'KQ?GPGQPSD~?', 'KGD?X?P`cB~?', 'KqI?O`QIOL?j', 'KoD@I_g_?e`e', 'KgA?gW_CWTN?', 'K`?_O`BBcI~?', 'KyGO_WI_?I_V', 'K`CcA?raaI@b']
unique = []
for i in non_minimal:
    if i not in unique:
        unique.append(i)
print (len(unique))
print (unique)
# Out:
# 10
# ['J@`KACXHf_?', 'K_OGPGRD@C}?', 'KQ?GPGQPSD~?', 'KGD?X?P`cB~?', 'KqI?O`QIOL?j', 'KoD@I_g_?e`e', 'KgA?gW_CWTN?', 'K`?_O`BBcI~?', 'KyGO_WI_?I_V', 'K`CcA?raaI@b']

# %%
graph_lst = []
minimal = []
for graph in list(graphs_2.split(",")):
    graph_lst.append(graph[1:])
graph_lst[-1] = graph_lst[-1][:-1]
print (graph_lst)
for graph in graph_lst:
    if graph not in non_minimal:
        minimal.append(graph)
print (len(minimal))
print (minimal)
# Out:
# ['I?qa``eeO', 'ICOedPKL?', 'J?GX?dH`f_?', 'J@`KACXHf_?', 'JsOH?`JH_i_', 'J@`ICC[Gv_?', 'J`hSA?hD_F_', 'JRPCSGoAgJ_', 'K_OGPGRD@C}?', 'K_GTAQOP@KbK', 'K@QCAGdA_c~?', 'KQ?GPGQPSD~?', 'KGD?X?P`cB~?', 'KqI?O`QIOL?j', 'KoD@I_g_?e`e', 'K_GP`GWBACoK', 'KgA?gW_CWTN?', 'KAICH@@DOT^?', 'Kko_GC`C?b`q', 'K`?_O`BBcI~?', 'K`?KA@se_YCX', 'Ks?I@?XDaTCi', 'Kt?G?DKOoqCo', 'KyGO_WI_?I_V', 'K`CcA?raaI@b', 'KqCaC?[I_J?Z', 'K`?LAQOP@KbK']
# 17
# ['I?qa``eeO', 'ICOedPKL?', 'J?GX?dH`f_?', 'JsOH?`JH_i_', 'J@`ICC[Gv_?', 'J`hSA?hD_F_', 'JRPCSGoAgJ_', 'K_GTAQOP@KbK', 'K@QCAGdA_c~?', 'K_GP`GWBACoK', 'KAICH@@DOT^?', 'Kko_GC`C?b`q', 'K`?KA@se_YCX', 'Ks?I@?XDaTCi', 'Kt?G?DKOoqCo', 'KqCaC?[I_J?Z', 'K`?LAQOP@KbK']

# %%
for graph in minimal:
    g = Graph(graph)
    print (len(g.degree_sequence()))
# Out:
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12

# %%
I?qa``eeO
ICOedPKL?
J?GX?dH`f_?
JsOH?`JH_i_
J@`ICC[Gv_?
J`hSA?hD_F_
JRPCSGoAgJ_
K_GTAQOP@KbK
K@QCAGdA_c~?
K_GP`GWBACoK
KAICH@@DOT^?
Kko_GC`C?b`q
K`?KA@se_YCX
Ks?I@?XDaTCi
Kt?G?DKOoqCo
KqCaC?[I_J?Z
K`?LAQOP@KbK
